# %% [markdown]
# # **Questions**

# %% [markdown]
# 2. Which is the most common profile of the immigrants into the OECD countries considering gender and studies?
# Alternative question: Which are the OECD countires where immigrant women have reached the highest integration rate in the labor market during the last ten years?

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/clean/immigrant_employment_OECD.csv')
data
# Out:
#          Country Place of birth Gender                Rate  Year        Unit  \
# 0      Australia   Foreign-born    Men     Employment rate  2000  Percentage
# 1      Australia   Foreign-born    Men     Employment rate  2001  Percentage
# 2      Australia   Foreign-born    Men     Employment rate  2002  Percentage
# 3      Australia   Foreign-born    Men     Employment rate  2003  Percentage
# 4      Australia   Foreign-born    Men     Employment rate  2004  Percentage
# ...          ...            ...    ...                 ...   ...         ...
# 12048  Lithuania    Native-born  Total   Unemployment rate  2021  Percentage
# 12049  Lithuania    Native-born  Total  Participation rate  2018  Percentage
# 12050  Lithuania    Native-born  Total  Participation rate  2019  Percentage
# 12051  Lithuania    Native-born  Total  Participation rate  2020  Percentage
# 12052  Lithuania    Native-born  Total  Participation rate  2021  Percentage
#
#        Value
# 0       74.0
# 1       73.9
# ...

# %% [markdown]
# Detailed examination of the Employment Rate by Country and Femenine Gender

# %%
def emp_rate_gender(data, year=int, gender= object):

    """"
    This function inputs a data base defined as data, a year from 2000 until 20121, and Gender = 'Women', 'Men'. 
    Depending on Gender and the year selected the function returns a data frame 
    including the columns = 'Country', 'Gender', 'Rate' always showing the value Employment rate in every row, 'Year', 'Unit' always showing the value Percentage in every row, and 'Value' corresponding to
    every single country included in the data frame called data and its employment rate by gender.

    """
    
    immi = data.copy().set_index('Place of birth')
    immi = immi.loc[['Foreign-born']]
    immi = immi[(immi['Year'] == year) & (immi['Rate'] == 'Employment rate') & (immi['Gender'] == gender)]

    max_immi1 = immi.pivot_table(index=['Country', 'Gender', 'Rate', 'Year'], aggfunc = {'sum'} )
    max_immi1

    max_immi2 = max_immi1.sort_values(by = ('Value', 'sum'), ascending=False).head(10)

    return max_immi2

# %%
emp_rate_gender(data, 2010, 'Women')
# Out:
#                                                    Unit Value
#                                                     sum   sum
# Country         Gender Rate            Year
# Iceland         Women  Employment rate 2010  Percentage  74.6
# Switzerland     Women  Employment rate 2010  Percentage  66.6
# Norway          Women  Employment rate 2010  Percentage  65.8
# Portugal        Women  Employment rate 2010  Percentage  64.5
# Canada          Women  Employment rate 2010  Percentage  63.4
# Hungary         Women  Employment rate 2010  Percentage  62.4
# Luxembourg      Women  Employment rate 2010  Percentage  61.9
# New Zealand     Women  Employment rate 2010  Percentage  61.0
# Australia       Women  Employment rate 2010  Percentage  60.7
# Denmark         Women  Employment rate 2010  Percentage  60.5
# Finland         Women  Employment rate 2010  Percentage  59.9
# Slovenia        Women  Employment rate 2010  Percentage  59.8
# ...

# %%
emp_rate_gender(data, 2011, 'Women')
# Out:
#                                                    Unit Value
#                                                     sum   sum
# Country     Gender Rate            Year
# Iceland     Women  Employment rate 2015  Percentage  76.8
# Israel      Women  Employment rate 2015  Percentage  76.2
# Switzerland Women  Employment rate 2015  Percentage  69.3
# New Zealand Women  Employment rate 2015  Percentage  66.7
# Estonia     Women  Employment rate 2015  Percentage  65.4
# Portugal    Women  Employment rate 2015  Percentage  65.2
# Chile       Women  Employment rate 2015  Percentage  65.1
# Canada      Women  Employment rate 2015  Percentage  64.2
# Norway      Women  Employment rate 2015  Percentage  63.8
# Luxembourg  Women  Employment rate 2015  Percentage  63.3

# %%
data_5 = emp_rate_gender(data, 2016, 'Women')
data_5
# Out:
#                                                   Unit Value
#                                                    sum   sum
# Country        Gender Rate            Year
# Iceland        Women  Employment rate 2016  Percentage  85.3
# Israel         Women  Employment rate 2016  Percentage  77.1
# Switzerland    Women  Employment rate 2016  Percentage  69.8
# New Zealand    Women  Employment rate 2016  Percentage  68.4
# Portugal       Women  Employment rate 2016  Percentage  67.8
# Estonia        Women  Employment rate 2016  Percentage  66.0
# Hungary        Women  Employment rate 2016  Percentage  65.5
# Canada         Women  Employment rate 2016  Percentage  65.3
# Norway         Women  Employment rate 2016  Percentage  64.3
# Czech Republic Women  Employment rate 2016  Percentage  63.3

# %%
data_6 = emp_rate_gender(data, 2017, 'Women')
data_6
# Out:
#                                                   Unit Value
#                                                    sum   sum
# Country        Gender Rate            Year
# Iceland        Women  Employment rate 2017  Percentage  87.3
# Israel         Women  Employment rate 2017  Percentage  76.9
# Portugal       Women  Employment rate 2017  Percentage  71.3
# Chile          Women  Employment rate 2017  Percentage  68.8
# Hungary        Women  Employment rate 2017  Percentage  68.2
# Czech Republic Women  Employment rate 2017  Percentage  67.9
# Switzerland    Women  Employment rate 2017  Percentage  67.9
# Canada         Women  Employment rate 2017  Percentage  66.9
# Estonia        Women  Employment rate 2017  Percentage  66.2
# Luxembourg     Women  Employment rate 2017  Percentage  65.7

# %%
data_7 = emp_rate_gender(data, 2018, 'Women')
data_7
# Out:
#                                                   Unit Value
#                                                    sum   sum
# Country        Gender Rate            Year
# Iceland        Women  Employment rate 2018  Percentage  78.0
# Israel         Women  Employment rate 2018  Percentage  77.0
# Portugal       Women  Employment rate 2018  Percentage  71.3
# New Zealand    Women  Employment rate 2018  Percentage  70.8
# Czech Republic Women  Employment rate 2018  Percentage  70.0
# Switzerland    Women  Employment rate 2018  Percentage  69.3
# Lithuania      Women  Employment rate 2018  Percentage  68.9
# Luxembourg     Women  Employment rate 2018  Percentage  67.2
# Canada         Women  Employment rate 2018  Percentage  66.6
# Estonia        Women  Employment rate 2018  Percentage  66.5

# %%
data_8 = emp_rate_gender(data, 2019, 'Women')
data_8
# Out:
#                                                    Unit Value
#                                                     sum   sum
# Country         Gender Rate            Year
# Iceland         Women  Employment rate 2019  Percentage  79.3
# Israel          Women  Employment rate 2019  Percentage  77.6
# Hungary         Women  Employment rate 2019  Percentage  73.8
# New Zealand     Women  Employment rate 2019  Percentage  71.7
# Portugal        Women  Employment rate 2019  Percentage  71.6
# Estonia         Women  Employment rate 2019  Percentage  71.2
# Switzerland     Women  Employment rate 2019  Percentage  70.3
# Lithuania       Women  Employment rate 2019  Percentage  69.6
# Czech Republic  Women  Employment rate 2019  Percentage  69.6
# Slovak Republic Women  Employment rate 2019  Percentage  69.0

# %%
data_9 = emp_rate_gender(data, 2020, 'Women')
data_9
# Out:
#                                                    Unit Value
#                                                     sum   sum
# Country         Gender Rate            Year
# Israel          Women  Employment rate 2020  Percentage  77.2
# Iceland         Women  Employment rate 2020  Percentage  76.2
# Estonia         Women  Employment rate 2020  Percentage  72.7
# New Zealand     Women  Employment rate 2020  Percentage  71.6
# Hungary         Women  Employment rate 2020  Percentage  71.1
# Switzerland     Women  Employment rate 2020  Percentage  70.4
# Chile           Women  Employment rate 2020  Percentage  70.3
# Czech Republic  Women  Employment rate 2020  Percentage  70.2
# Slovak Republic Women  Employment rate 2020  Percentage  69.6
# Portugal        Women  Employment rate 2020  Percentage  69.6

# %%
data_10 = emp_rate_gender(data, 2021, 'Women')
data_10
# Out:
#                                                   Unit Value
#                                                    sum   sum
# Country        Gender Rate            Year
# Israel         Women  Employment rate 2021  Percentage  76.9
# Hungary        Women  Employment rate 2021  Percentage  76.1
# Poland         Women  Employment rate 2021  Percentage  73.8
# Portugal       Women  Employment rate 2021  Percentage  72.3
# Iceland        Women  Employment rate 2021  Percentage  72.2
# United Kingdom Women  Employment rate 2021  Percentage  70.1
# Czech Republic Women  Employment rate 2021  Percentage  69.3
# Switzerland    Women  Employment rate 2021  Percentage  68.8
# Luxembourg     Women  Employment rate 2021  Percentage  68.2
# Australia      Women  Employment rate 2021  Percentage  67.8

# %%
dfs = [data_1, data_2, data_3, data_4, data_5, data_6, data_7, data_8, data_9, data_10  ]

result = pd.concat(dfs).reset_index()

result
# Out:
#            Country Gender             Rate  Year        Unit Value
#                                                          sum   sum
# 0          Iceland  Women  Employment rate  2012  Percentage  75.8
# 1           Israel  Women  Employment rate  2012  Percentage  72.0
# 2      Switzerland  Women  Employment rate  2012  Percentage  68.2
# 3           Norway  Women  Employment rate  2012  Percentage  66.7
# 4         Portugal  Women  Employment rate  2012  Percentage  64.8
# ..             ...    ...              ...   ...         ...   ...
# 95  United Kingdom  Women  Employment rate  2021  Percentage  70.1
# 96  Czech Republic  Women  Employment rate  2021  Percentage  69.3
# 97     Switzerland  Women  Employment rate  2021  Percentage  68.8
# 98      Luxembourg  Women  Employment rate  2021  Percentage  68.2
# 99       Australia  Women  Employment rate  2021  Percentage  67.8
#
# [100 rows x 6 columns]

# %%
result.columns = result.columns.droplevel(1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.lineplot(data=result, x='Year', y='Value', hue='Country', ax=ax)
plt.show()
